# %%
import keras
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import sklearn
from keras.models import load_model

# %%
def find_genre(test_path, model_path):
    model = load_model(model_path) 
    img = image.load_img(test_path,target_size=(200,150,3))
    img = image.img_to_array(img)
    img = img/255
    prob = model.predict(img.reshape(1,200,150,3))

    top_3 = np.argsort(prob[0])[:-4:-1]

    column_lookups = pd.read_csv("Encoded_data_column_lookup.csv", delimiter=" ")
    classes = np.asarray(column_lookups.iloc[1:29, 0])

    for i in range(3):
        print("{}".format(classes[top_3[i]])+" ({:.3})".format(prob[0][top_3[i]]))
    plt.imshow(img)

# %%
find_genre("Poster-images-test/Gladiator.jpg",'Model_4d.h5')
# Out:
# Family (0.736)
# Adult (0.385)
# War (0.234)

# %%
find_genre("Poster-images-test/Life-of-Pi.jpg",'Model_4d.h5')
# Out:
# Adult (0.718)
# Animation (0.638)
# Family (0.291)

# %%
find_genre("Poster-images-test/i-robot.jpg",'Model_6c.h5')
# Out:
# Family (0.495)
# Crime (0.311)
# Sci-Fi (0.148)

# %%
find_genre("Poster-images-test/Matrix.jpg",'Model_6c.h5')
# Out:
# Family (0.495)
# Crime (0.311)
# Sci-Fi (0.148)

# %%
find_genre("Poster-images-test/Pianist.jpg",'Model_4d.h5')
# Out:
# Family (0.614)
# War (0.428)
# Music (0.404)
